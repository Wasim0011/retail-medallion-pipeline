# %%
# %run ./pipeline_config

# %%
# %sql
-- Cell 1 & 2 (Combined)
CREATE SCHEMA IF NOT EXISTS capstone_retail_db;

-- This creates a professional 'managed' storage area for your files
CREATE VOLUME IF NOT EXISTS capstone_retail_db.retail_storage;

# %%
# Now that the catalog 'workspace' is confirmed, this will work perfectly
layers = ["raw", "bronze", "silver", "gold"]

for layer in layers:
    path = PATHS[layer]
    dbutils.fs.mkdirs(path)
    print(f"✅ Successfully Created: {path}")

# %%
# %sql
SHOW CATALOGS;
